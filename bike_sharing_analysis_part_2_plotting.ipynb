# %% [markdown]
# # Plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_2 = pd.read_csv('data_sets/dc_bikes_2.csv', index_col=0)

# %%
df_2.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2011-01-01 00:00:00        81        0.0     3.0        13.0     16  2011
# 2011-01-01 01:00:00        80        0.0     8.0        32.0     40  2011
# 2011-01-01 02:00:00        80        0.0     5.0        27.0     32  2011
# 2011-01-01 03:00:00        75        0.0     3.0        10.0     13  2011
# 2011-01-01 04:00:00        75        0.0     0.0         1.0      1  2011
#
#                      month_number    month  day_of_month  week_day  hour_day  \
# datetime
# 2011-01-01 00:00:00             1  January             1  Saturday         0
# 2011-01-01 01:00:00             1  January             1  Saturday         1
# 2011-01-01 02:00:00             1  January             1  Saturday         2
# 2011-01-01 03:00:00             1  January             1  Saturday         3
# 2011-01-01 04:00:00             1  January             1  Saturday         4
#
#                     season_name  hour_of_day part_of_day
# datetime
# 2011-01-01 00:00:00      winter            0       night
# 2011-01-01 01:00:00      winter            1       night
# 2011-01-01 02:00:00      winter            2       night
# 2011-01-01 03:00:00      winter            3       night
# 2011-01-01 04:00:00      winter            4       night

# %%
df_2.index
# Out:
# Index(['2011-01-01 00:00:00', '2011-01-01 01:00:00', '2011-01-01 02:00:00',
#        '2011-01-01 03:00:00', '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#        '2011-01-01 06:00:00', '2011-01-01 07:00:00', '2011-01-01 08:00:00',
#        '2011-01-01 09:00:00',
#        ...
#        '2012-12-31 14:00:00', '2012-12-31 15:00:00', '2012-12-31 16:00:00',
#        '2012-12-31 17:00:00', '2012-12-31 18:00:00', '2012-12-31 19:00:00',
#        '2012-12-31 20:00:00', '2012-12-31 21:00:00', '2012-12-31 22:00:00',
#        '2012-12-31 23:00:00'],
#       dtype='object', name='datetime', length=17379)

# %%
df_2.index = pd.to_datetime(df_2.index)

# %%
df_2.index
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                ...
#                '2012-12-31 14:00:00', '2012-12-31 15:00:00',
#                '2012-12-31 16:00:00', '2012-12-31 17:00:00',
#                '2012-12-31 18:00:00', '2012-12-31 19:00:00',
#                '2012-12-31 20:00:00', '2012-12-31 21:00:00',
#                '2012-12-31 22:00:00', '2012-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=17379, freq=None)

# %% [markdown]
# #### 2. Plot small sections of the count data over time (1 day, 1 week, etc.)

# %% [markdown]
# #### 2.1.  Day Plot:

# %%
df_2.loc['2011-01-01'].head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2011-01-01 00:00:00        81        0.0     3.0        13.0     16  2011
# 2011-01-01 01:00:00        80        0.0     8.0        32.0     40  2011
# 2011-01-01 02:00:00        80        0.0     5.0        27.0     32  2011
# 2011-01-01 03:00:00        75        0.0     3.0        10.0     13  2011
# 2011-01-01 04:00:00        75        0.0     0.0         1.0      1  2011
#
#                      month_number    month  day_of_month  week_day  hour_day  \
# datetime
# 2011-01-01 00:00:00             1  January             1  Saturday         0
# 2011-01-01 01:00:00             1  January             1  Saturday         1
# 2011-01-01 02:00:00             1  January             1  Saturday         2
# 2011-01-01 03:00:00             1  January             1  Saturday         3
# 2011-01-01 04:00:00             1  January             1  Saturday         4
#
#                     season_name  hour_of_day part_of_day
# datetime
# 2011-01-01 00:00:00      winter            0       night
# 2011-01-01 01:00:00      winter            1       night
# 2011-01-01 02:00:00      winter            2       night
# 2011-01-01 03:00:00      winter            3       night
# 2011-01-01 04:00:00      winter            4       night

# %%
#1 day count: January 1st, 2011:

day_count = df_2.loc['2011-01-01']['count'].sum()
day_count
# Out:
# 985

# %%
df_2.loc['2011-01-01']['count'].max()
# Out:
# 110

# %%
# Option 1: Creat a new data frame only with the column 'count' and the index:

# 1. Create the data series:

ds_day1= df_2.loc['2011-01-01']['count']
ds_day1.head()
# Out:
# datetime
# 2011-01-01 00:00:00    16
# 2011-01-01 01:00:00    40
# 2011-01-01 02:00:00    32
# 2011-01-01 03:00:00    13
# 2011-01-01 04:00:00     1
# Name: count, dtype: int64

# %%
# 2. Create the plot from the data series:

ds_day1.plot(x= 'datetime', y= 'count',label= 'count')
plt.legend()
plt.show()

# %%
# Option 2: Creat a new data frame only with the columns I need:

# 1. Create the data frame with the needed columns:

df_day= df_2.loc['2011-01-01'][['count','hour_day']]
df_day.head()
# Out:
#                      count  hour_day
# datetime
# 2011-01-01 00:00:00     16         0
# 2011-01-01 01:00:00     40         1
# 2011-01-01 02:00:00     32         2
# 2011-01-01 03:00:00     13         3
# 2011-01-01 04:00:00      1         4

# %%
# 2. Plot the information from the columns. 

#plt.figure(figsize= (6,10), dpi = 80)
sns.lineplot(x= 'hour_day', y= 'count', data= df_day,label= 'count')
plt.legend()
plt.show()

# %%
# Option 3: Plot directly from the original data frame:

#plt.figure(figsize= (8,10), dpi = 80)

# 1. Extract the information from the day needed: 

day_one= df_2.loc['2011-01-01']

# 2. Use this variable in the plotting code line:

sns.lineplot(x= day_one['hour_day'], y = df_2['count'], data= df_2, label= 'count')

plt.show()

# %%
# Alternative to Option 3: Do not create a new variable, use the .loc directly
# on the ploting line:

sns.lineplot(x= df_2.loc['2011-01-01']['hour_day'], y = df_2['count'], data= df_2, label= 'count' )
plt.legend()
plt.show()

# %% [markdown]
# #### 2.2.  Week Plot:

# %%
week_1 = df_2.loc['2011-01-01':'2011-01-07']

sns.lineplot(x= df_2['day_of_month'], y = week_1['count'], data= df_2, label= 'count', ci = None )
plt.legend()
plt.show()

# %%
week_2 = df_2.loc['2011-01-08':'2011-01-15']

sns.lineplot(x= week_2['day_of_month'], y = week_2['count'], data= df_2, label= 'count',ci = None )
plt.legend()
plt.show()

# %% [markdown]
# #### 2.3.  Month Plot:

# %%
january = df_2[(df_2['month'] == 'January') & (df_2['year'] == 2011)]
january
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2011-01-31 19:00:00       1        0           1        1  12.30  15.910
# 2011-01-31 20:00:00       1        0           1        3   6.56   8.335
# 2011-01-31 21:00:00       1        0           1        3   6.56   9.850
# 2011-01-31 22:00:00       1        0           1        2   6.56   9.090
# 2011-01-31 23:00:00       1        0           1        2   6.56   9.850
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2011-01-01 00:00:00        81     0.0000     3.0        13.0     16  2011
# 2011-01-01 01:00:00        80     0.0000     8.0        32.0     40  2011
# 2011-01-01 02:00:00        80     0.0000     5.0        27.0     32  2011
# 2011-01-01 03:00:00        75     0.0000     3.0        10.0     13  2011
# 2011-01-01 04:00:00        75     0.0000     0.0         1.0      1  2011
# ...                       ...        ...     ...         ...    ...   ...
# 2011-01-31 19:00:00        61     7.0015     NaN         NaN    137  2011
# 2011-01-31 20:00:00        59    11.0014     NaN         NaN     32  2011
# 2011-01-31 21:00:00        59     6.0032     NaN         NaN     23  2011
# 2011-01-31 22:00:00        59     7.0015     NaN         NaN     22  2011
# 2011-01-31 23:00:00        64     6.0032     NaN         NaN     12  2011
#
#                      month_number    month  day_of_month  week_day  hour_day  \
# datetime
# 2011-01-01 00:00:00             1  January             1  Saturday         0
# 2011-01-01 01:00:00             1  January             1  Saturday         1
# 2011-01-01 02:00:00             1  January             1  Saturday         2
# 2011-01-01 03:00:00             1  January             1  Saturday         3
# 2011-01-01 04:00:00             1  January             1  Saturday         4
# ...                           ...      ...           ...       ...       ...
# 2011-01-31 19:00:00             1  January            31    Monday        19
# 2011-01-31 20:00:00             1  January            31    Monday        20
# 2011-01-31 21:00:00             1  January            31    Monday        21
# 2011-01-31 22:00:00             1  January            31    Monday        22
# 2011-01-31 23:00:00             1  January            31    Monday        23
#
#                     season_name  hour_of_day part_of_day
# datetime
# 2011-01-01 00:00:00      winter            0       night
# 2011-01-01 01:00:00      winter            1       night
# 2011-01-01 02:00:00      winter            2       night
# 2011-01-01 03:00:00      winter            3       night
# 2011-01-01 04:00:00      winter            4       night
# ...                         ...          ...         ...
# 2011-01-31 19:00:00      winter           19     evening
# 2011-01-31 20:00:00      winter           20     evening
# 2011-01-31 21:00:00      winter           21     evening
# 2011-01-31 22:00:00      winter           22     evening
# 2011-01-31 23:00:00      winter           23     evening
#
# [688 rows x 20 columns]

# %%
sns.lineplot(x= january['day_of_month'], y = df_2['count'], data= df_2, label= 'count',ci = None )
plt.legend()
plt.show()

# %% [markdown]
# #### 2.4.  Quarter Plot:

# %%
Q1_2011 = df_2.loc['2011-01-01':'2011-03-31']
sns.lineplot(x= Q1_2011['month'], y = df_2['count'], data= df_2, label= 'count',ci = None )
plt.legend()
plt.show()

# %%
Q1_2011_2 = df_2[((df_2['month'] == 'January') | (df_2['month'] == 'February')
                   | (df_2['month'] == 'March')) & (df_2['year'] == 2011)]
Q1_2011_2
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2011-03-31 19:00:00       2        0           1        2  12.30  15.150
# 2011-03-31 20:00:00       2        0           1        3  11.48  12.880
# 2011-03-31 21:00:00       2        0           1        2  11.48  13.635
# 2011-03-31 22:00:00       2        0           1        3  11.48  13.635
# 2011-03-31 23:00:00       2        0           1        3  10.66  12.880
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2011-01-01 00:00:00        81     0.0000     3.0        13.0     16  2011
# 2011-01-01 01:00:00        80     0.0000     8.0        32.0     40  2011
# 2011-01-01 02:00:00        80     0.0000     5.0        27.0     32  2011
# 2011-01-01 03:00:00        75     0.0000     3.0        10.0     13  2011
# 2011-01-01 04:00:00        75     0.0000     0.0         1.0      1  2011
# ...                       ...        ...     ...         ...    ...   ...
# 2011-03-31 19:00:00        87     8.9981     NaN         NaN    136  2011
# 2011-03-31 20:00:00        93    19.0012     NaN         NaN     46  2011
# 2011-03-31 21:00:00        93    11.0014     NaN         NaN     70  2011
# 2011-03-31 22:00:00        93    16.9979     NaN         NaN     29  2011
# 2011-03-31 23:00:00       100    11.0014     NaN         NaN     18  2011
#
#                      month_number    month  day_of_month  week_day  hour_day  \
# datetime
# 2011-01-01 00:00:00             1  January             1  Saturday         0
# 2011-01-01 01:00:00             1  January             1  Saturday         1
# 2011-01-01 02:00:00             1  January             1  Saturday         2
# 2011-01-01 03:00:00             1  January             1  Saturday         3
# 2011-01-01 04:00:00             1  January             1  Saturday         4
# ...                           ...      ...           ...       ...       ...
# 2011-03-31 19:00:00             3    March            31  Thursday        19
# 2011-03-31 20:00:00             3    March            31  Thursday        20
# 2011-03-31 21:00:00             3    March            31  Thursday        21
# 2011-03-31 22:00:00             3    March            31  Thursday        22
# 2011-03-31 23:00:00             3    March            31  Thursday        23
#
#                     season_name  hour_of_day part_of_day
# datetime
# 2011-01-01 00:00:00      winter            0       night
# 2011-01-01 01:00:00      winter            1       night
# 2011-01-01 02:00:00      winter            2       night
# 2011-01-01 03:00:00      winter            3       night
# 2011-01-01 04:00:00      winter            4       night
# ...                         ...          ...         ...
# 2011-03-31 19:00:00      spring           19     evening
# 2011-03-31 20:00:00      spring           20     evening
# 2011-03-31 21:00:00      spring           21     evening
# 2011-03-31 22:00:00      spring           22     evening
# 2011-03-31 23:00:00      spring           23     evening
#
# [2067 rows x 20 columns]

# %%
sns.lineplot(x= Q1_2011_2['month'], y = Q1_2011_2['count'], data= df_2, label= 'count',ci = None )
plt.legend()
plt.show()

# %% [markdown]
# #### 2.5.  Semester Plot:

# %%
S1_2011 = df_2.loc['2011-01-01':'2011-06-30']
sns.lineplot(x= S1_2011['month'], y = S1_2011['count'], data= df_2, label= 'count',ci = None )
plt.legend()
plt.show()

# %% [markdown]
# #### 2.6.  Year Plot:

# %%
plt.figure(figsize= (15,5), dpi = 80)

Y1_2011 = df_2.loc['2011-01-01':'2011-12-31']
sns.lineplot(x= df_2['month'], y = df_2['count'], data= df_2, label= 'count',ci = None )
plt.legend()
plt.show()

# %% [markdown]
# #### 2.7.  Two Years Plot:

# %%
df_2['rolling_mean'] = df_2['count'].rolling(window=1000).mean()

# %%
plt.figure(figsize= (15,5), dpi = 80)

sns.lineplot(x= df_2.index, y = df_2['rolling_mean'], data= df_2, label= 'count',ci = None )
plt.legend()
plt.show()

# %%
df_2['rolling_mean'].max()
# Out:
# 288.347

# %%
df_2['month'][df_2['rolling_mean'] == df_2['rolling_mean'].max()]
# Out:
# datetime
# 2012-10-18 22:00:00    October
# Name: month, dtype: object

# %%
df_2['rolling_mean'].min()
# Out:
# 62.14

# %%
df_2['month'][df_2['rolling_mean'] == df_2['rolling_mean'].min()]
# Out:
# datetime
# 2011-02-14 07:00:00    February
# Name: month, dtype: object

# %% [markdown]
# ### 3. Create a part_of_day column for the bike data. It should have the following labels: morning, afternoon, evening, night

# %%
df_2['hour_of_day'] =df_2.index.hour
df_2.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  ...  year  \
# datetime                                                      ...
# 2011-01-01 00:00:00        81        0.0     3.0        13.0  ...  2011
# 2011-01-01 01:00:00        80        0.0     8.0        32.0  ...  2011
# 2011-01-01 02:00:00        80        0.0     5.0        27.0  ...  2011
# 2011-01-01 03:00:00        75        0.0     3.0        10.0  ...  2011
# 2011-01-01 04:00:00        75        0.0     0.0         1.0  ...  2011
#
#                      month_number    month day_of_month  week_day hour_day  \
# datetime
# 2011-01-01 00:00:00             1  January            1  Saturday        0
# 2011-01-01 01:00:00             1  January            1  Saturday        1
# 2011-01-01 02:00:00             1  January            1  Saturday        2
# 2011-01-01 03:00:00             1  January            1  Saturday        3
# 2011-01-01 04:00:00             1  January            1  Saturday        4
#
#                      season_name hour_of_day  part_of_day rolling_mean
# datetime
# 2011-01-01 00:00:00       winter           0        night          NaN
# 2011-01-01 01:00:00       winter           1        night          NaN
# 2011-01-01 02:00:00       winter           2        night          NaN
# 2011-01-01 03:00:00       winter           3        night          NaN
# 2011-01-01 04:00:00       winter           4        night          NaN
#
# [5 rows x 21 columns]

# %%
df_2['hour_of_day'].min(), df_2['hour_of_day'].max()
# Out:
# (0, 23)

# %% [markdown]
# #### Option 1: dividing the day in 3 segments as done in Latinameria: Morning, Afternoon, Evening

# %%
time_labels = ['evening_2','morning', 'afternoon', 'evening']
bin_boundaries = [-0.1, 4.9, 12, 18, 23.9]

# %%
df_2['part_of_day']= pd.cut(df_2['hour_of_day'], bins=bin_boundaries, labels=time_labels)

# %%
df_2.tail()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#                      humidity  windspeed  casual  registered  ...  year  \
# datetime                                                      ...
# 2012-12-31 19:00:00        60    11.0014     NaN         NaN  ...  2012
# 2012-12-31 20:00:00        60    11.0014     NaN         NaN  ...  2012
# 2012-12-31 21:00:00        60    11.0014     NaN         NaN  ...  2012
# 2012-12-31 22:00:00        56     8.9981     NaN         NaN  ...  2012
# 2012-12-31 23:00:00        65     8.9981     NaN         NaN  ...  2012
#
#                      month_number     month day_of_month  week_day hour_day  \
# datetime
# 2012-12-31 19:00:00            12  December           31    Monday       19
# 2012-12-31 20:00:00            12  December           31    Monday       20
# 2012-12-31 21:00:00            12  December           31    Monday       21
# 2012-12-31 22:00:00            12  December           31    Monday       22
# 2012-12-31 23:00:00            12  December           31    Monday       23
#
#                      season_name hour_of_day  part_of_day rolling_mean
# datetime
# 2012-12-31 19:00:00       winter          19      evening      171.682
# 2012-12-31 20:00:00       winter          20      evening      171.764
# 2012-12-31 21:00:00       winter          21      evening      171.819
# 2012-12-31 22:00:00       winter          22      evening      171.852
# 2012-12-31 23:00:00       winter          23      evening      171.869
#
# [5 rows x 21 columns]

# %%
df_2 = df_2[df_2['part_of_day']== 'evening_2'].replace({'evening_2': 'evening'})
df_2.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  ...  year  \
# datetime                                                      ...
# 2011-01-01 00:00:00        81        0.0     3.0        13.0  ...  2011
# 2011-01-01 01:00:00        80        0.0     8.0        32.0  ...  2011
# 2011-01-01 02:00:00        80        0.0     5.0        27.0  ...  2011
# 2011-01-01 03:00:00        75        0.0     3.0        10.0  ...  2011
# 2011-01-01 04:00:00        75        0.0     0.0         1.0  ...  2011
#
#                      month_number    month day_of_month  week_day hour_day  \
# datetime
# 2011-01-01 00:00:00             1  January            1  Saturday        0
# 2011-01-01 01:00:00             1  January            1  Saturday        1
# 2011-01-01 02:00:00             1  January            1  Saturday        2
# 2011-01-01 03:00:00             1  January            1  Saturday        3
# 2011-01-01 04:00:00             1  January            1  Saturday        4
#
#                      season_name hour_of_day  part_of_day rolling_mean
# datetime
# 2011-01-01 00:00:00       winter           0      evening          NaN
# 2011-01-01 01:00:00       winter           1      evening          NaN
# 2011-01-01 02:00:00       winter           2      evening          NaN
# 2011-01-01 03:00:00       winter           3      evening          NaN
# 2011-01-01 04:00:00       winter           4      evening          NaN
#
# [5 rows x 21 columns]

# %%
df_2['part_of_day'].unique()
# Out:
# ['evening']
# Categories (3, object): ['morning' < 'afternoon' < 'evening']

# %% [markdown]
# #### Option 2: dividing the day in 4 segments: Morning, Afternoon, Evening, night.

# %%
time_labels = ['night','morning', 'afternoon', 'evening']
bin_boundaries = [-0.1, 4.9, 12, 18, 23.9]

# %%
df_2['part_of_day']= pd.cut(df_2['hour_of_day'], bins=bin_boundaries, labels=time_labels)

# %%
df_2.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  ...  year  \
# datetime                                                      ...
# 2011-01-01 00:00:00        81        0.0     3.0        13.0  ...  2011
# 2011-01-01 01:00:00        80        0.0     8.0        32.0  ...  2011
# 2011-01-01 02:00:00        80        0.0     5.0        27.0  ...  2011
# 2011-01-01 03:00:00        75        0.0     3.0        10.0  ...  2011
# 2011-01-01 04:00:00        75        0.0     0.0         1.0  ...  2011
#
#                      month_number    month day_of_month  week_day hour_day  \
# datetime
# 2011-01-01 00:00:00             1  January            1  Saturday        0
# 2011-01-01 01:00:00             1  January            1  Saturday        1
# 2011-01-01 02:00:00             1  January            1  Saturday        2
# 2011-01-01 03:00:00             1  January            1  Saturday        3
# 2011-01-01 04:00:00             1  January            1  Saturday        4
#
#                      season_name hour_of_day  part_of_day rolling_mean
# datetime
# 2011-01-01 00:00:00       winter           0        night          NaN
# 2011-01-01 01:00:00       winter           1        night          NaN
# 2011-01-01 02:00:00       winter           2        night          NaN
# 2011-01-01 03:00:00       winter           3        night          NaN
# 2011-01-01 04:00:00       winter           4        night          NaN
#
# [5 rows x 21 columns]

# %%
df_2.tail()
# Out:
#                      season  holiday  workingday  weather  temp  atemp  \
# datetime
# 2012-12-31 00:00:00       1        0           1        1  7.38  9.090
# 2012-12-31 01:00:00       1        0           1        1  7.38  9.090
# 2012-12-31 02:00:00       1        0           1        1  6.56  8.335
# 2012-12-31 03:00:00       1        0           1        1  6.56  9.090
# 2012-12-31 04:00:00       1        0           1        1  5.74  8.335
#
#                      humidity  windspeed  casual  registered  ...  year  \
# datetime                                                      ...
# 2012-12-31 00:00:00        55    12.9980     NaN         NaN  ...  2012
# 2012-12-31 01:00:00        55    12.9980     NaN         NaN  ...  2012
# 2012-12-31 02:00:00        59    11.0014     NaN         NaN  ...  2012
# 2012-12-31 03:00:00        59     7.0015     NaN         NaN  ...  2012
# 2012-12-31 04:00:00        69     7.0015     NaN         NaN  ...  2012
#
#                      month_number     month day_of_month  week_day hour_day  \
# datetime
# 2012-12-31 00:00:00            12  December           31    Monday        0
# 2012-12-31 01:00:00            12  December           31    Monday        1
# 2012-12-31 02:00:00            12  December           31    Monday        2
# 2012-12-31 03:00:00            12  December           31    Monday        3
# 2012-12-31 04:00:00            12  December           31    Monday        4
#
#                      season_name hour_of_day  part_of_day rolling_mean
# datetime
# 2012-12-31 00:00:00       winter           0        night      175.458
# 2012-12-31 01:00:00       winter           1        night      175.332
# 2012-12-31 02:00:00       winter           2        night      174.949
# 2012-12-31 03:00:00       winter           3        night      174.288
# 2012-12-31 04:00:00       winter           4        night      174.012
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 4. Group by a time feature and observe grouped means

# %% [markdown]
# #### Group by a time feature and observe grouped means

# %%
df_2.groupby('year')['temp'].mean()
# Out:
# year
# 2011    18.427534
# 2012    18.982524
# Name: temp, dtype: float64

# %%
df_2.groupby(['year','month'])['temp'].mean()
# Out:
# year  month
# 2011  April        17.291544
#       August       26.726533
#       December     12.138158
#       February     10.056860
#       January       7.283150
#       July         28.636516
#       June         25.950267
#       March        11.944476
#       May          21.039613
#       November     14.875570
#       October      17.614026
#       September    23.696327
# 2012  April        17.275405
#       August       27.001806
#       December     12.433987
#       February     11.846383
#       January      10.320132
#       July         28.430194
#       June         25.042800
#       March        17.007013
#       May          23.049935
#       November     12.061757
#       October      19.011644
#       September    23.348133
# Name: temp, dtype: float64

# %%
df_2[(df_2['month'] == 'January') | (df_2['month'] == 'February')].groupby('year')['temp'].mean()
# Out:
# year
# 2011     8.636452
# 2012    11.054608
# Name: temp, dtype: float64

# %%
df_2[(df_2['month'] == 'June') | (df_2['month'] == 'July')].groupby('year')['temp'].mean()
# Out:
# year
# 2011    27.315410
# 2012    26.764262
# Name: temp, dtype: float64

# %%
df_2.groupby('year')['humidity'].mean()
# Out:
# year
# 2011    73.30879
# 2012    70.04870
# Name: humidity, dtype: float64

# %%
df_2.groupby('year')['windspeed'].mean()
# Out:
# year
# 2011    10.444967
# 2012    10.510068
# Name: windspeed, dtype: float64

# %%
df_2.groupby('year')['count'].sum()
# Out:
# year
# 2011    40552
# 2012    53656
# Name: count, dtype: int64

# %% [markdown]
# #### Make subset of data which only includes January 2011 observation. Add rolling average of the count to the new subset dataframe and plot the rolling average and count versus time.

# %%
january_2011= df_2[((df_2['month'] == 'January') & (df_2['year'] == 2011))]

# %%
rolling_mean_jan_2011 = january_2011['count'].rolling(window=10).mean()

# %%
#plt.figure(figsize= (15,5), dpi = 80)

sns.lineplot(x= january_2011['day_of_month'], y = rolling_mean_jan_2011, data= df_2, label= 'count',ci = None )
plt.legend()
plt.show()

# %%
df_2.columns
# Out:
# Index(['season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'casual', 'registered', 'count', 'year',
#        'month_number', 'month', 'day_of_month', 'week_day', 'hour_day',
#        'season_name', 'hour_of_day', 'part_of_day', 'rolling_mean'],
#       dtype='object')

# %%
# Drop columns that are not needed

df_dt2 = df_2.drop(['season', 'holiday','workingday','weather','temp','atemp','humidity','windspeed','casual','year','month_number', 'month', 'day_of_month', 'week_day', 'hour_day','season_name', 'hour_of_day', 'part_of_day', 'rolling_mean'], axis=1)
df_dt2
# Out:
#                      registered  count
# datetime
# 2011-01-01 00:00:00        13.0     16
# 2011-01-01 01:00:00        32.0     40
# 2011-01-01 02:00:00        27.0     32
# 2011-01-01 03:00:00        10.0     13
# 2011-01-01 04:00:00         1.0      1
# ...                         ...    ...
# 2012-12-31 00:00:00         NaN      9
# 2012-12-31 01:00:00         NaN      5
# 2012-12-31 02:00:00         NaN      3
# 2012-12-31 03:00:00         NaN      2
# 2012-12-31 04:00:00         NaN      2
#
# [3559 rows x 2 columns]

# %%
# Selecting columns option to reduce the table

df_dt2_2= df_2[['count','year','month','day_of_month','week_day','month_number']]
df_dt2_2
# Out:
#                      count  year     month  day_of_month  week_day  \
# datetime
# 2011-01-01 00:00:00     16  2011   January             1  Saturday
# 2011-01-01 01:00:00     40  2011   January             1  Saturday
# 2011-01-01 02:00:00     32  2011   January             1  Saturday
# 2011-01-01 03:00:00     13  2011   January             1  Saturday
# 2011-01-01 04:00:00      1  2011   January             1  Saturday
# ...                    ...   ...       ...           ...       ...
# 2012-12-31 00:00:00      9  2012  December            31    Monday
# 2012-12-31 01:00:00      5  2012  December            31    Monday
# 2012-12-31 02:00:00      3  2012  December            31    Monday
# 2012-12-31 03:00:00      2  2012  December            31    Monday
# 2012-12-31 04:00:00      2  2012  December            31    Monday
#
#                      month_number
# datetime
# 2011-01-01 00:00:00             1
# 2011-01-01 01:00:00             1
# 2011-01-01 02:00:00             1
# 2011-01-01 03:00:00             1
# 2011-01-01 04:00:00             1
# ...                           ...
# 2012-12-31 00:00:00            12
# 2012-12-31 01:00:00            12
# 2012-12-31 02:00:00            12
# 2012-12-31 03:00:00            12
# 2012-12-31 04:00:00            12
#
# [3559 rows x 6 columns]

# %%
df_dt2_2.head()
# Out:
#                      count  year    month  day_of_month  week_day  \
# datetime
# 2011-01-01 00:00:00     16  2011  January             1  Saturday
# 2011-01-01 01:00:00     40  2011  January             1  Saturday
# 2011-01-01 02:00:00     32  2011  January             1  Saturday
# 2011-01-01 03:00:00     13  2011  January             1  Saturday
# 2011-01-01 04:00:00      1  2011  January             1  Saturday
#
#                      month_number
# datetime
# 2011-01-01 00:00:00             1
# 2011-01-01 01:00:00             1
# 2011-01-01 02:00:00             1
# 2011-01-01 03:00:00             1
# 2011-01-01 04:00:00             1

# %%
# Transform 'year' column type from 'int' to 'str' to later concatinate.

df_dt2_2['year']= df_dt2_2['year'].astype(str)
# Out:
# /var/folders/yq/6pm1lcds6ln5qlsjc5y8fly00000gn/T/ipykernel_4536/303696026.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt2_2['year']= df_dt2_2['year'].astype(str)

# %%
df_dt2_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3559 entries, 2011-01-01 00:00:00 to 2012-12-31 04:00:00
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   count         3559 non-null   int64
#  1   year          3559 non-null   object
#  2   month         3559 non-null   object
#  3   day_of_month  3559 non-null   int64
#  4   week_day      3559 non-null   object
#  5   month_number  3559 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 194.6+ KB

# %%
# Transform 'month_number' column type from 'int' to 'str' to later concatinate.

df_dt2_2['month_number']= df_dt2_2['month_number'].astype(str)
# Out:
# /var/folders/yq/6pm1lcds6ln5qlsjc5y8fly00000gn/T/ipykernel_4536/566047724.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt2_2['month_number']= df_dt2_2['month_number'].astype(str)

# %%
df_dt2_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3559 entries, 2011-01-01 00:00:00 to 2012-12-31 04:00:00
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   count         3559 non-null   int64
#  1   year          3559 non-null   object
#  2   month         3559 non-null   object
#  3   day_of_month  3559 non-null   int64
#  4   week_day      3559 non-null   object
#  5   month_number  3559 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 194.6+ KB

# %%
# Concatinate 'year' and 'month_number' to create a new column called 'date' as 
# string type.

df_dt2_2['date'] = pd.to_datetime(df_dt2_2['year'] + '/' + df_dt2_2['month_number'])
df_dt2_2
# Out:
# /var/folders/yq/6pm1lcds6ln5qlsjc5y8fly00000gn/T/ipykernel_4536/823846508.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt2_2['date'] = pd.to_datetime(df_dt2_2['year'] + '/' + df_dt2_2['month_number'])
#                      count  year     month  day_of_month  week_day  \
# datetime
# 2011-01-01 00:00:00     16  2011   January             1  Saturday
# 2011-01-01 01:00:00     40  2011   January             1  Saturday
# 2011-01-01 02:00:00     32  2011   January             1  Saturday
# 2011-01-01 03:00:00     13  2011   January             1  Saturday
# 2011-01-01 04:00:00      1  2011   January             1  Saturday
# ...                    ...   ...       ...           ...       ...
# 2012-12-31 00:00:00      9  2012  December            31    Monday
# 2012-12-31 01:00:00      5  2012  December            31    Monday
# 2012-12-31 02:00:00      3  2012  December            31    Monday
# 2012-12-31 03:00:00      2  2012  December            31    Monday
# 2012-12-31 04:00:00      2  2012  December            31    Monday
#
#                     month_number       date
# datetime
# 2011-01-01 00:00:00            1 2011-01-01
# 2011-01-01 01:00:00            1 2011-01-01
# 2011-01-01 02:00:00            1 2011-01-01
# 2011-01-01 03:00:00            1 2011-01-01
# 2011-01-01 04:00:00            1 2011-01-01
# ...                          ...        ...
# 2012-12-31 00:00:00           12 2012-12-01
# 2012-12-31 01:00:00           12 2012-12-01
# 2012-12-31 02:00:00           12 2012-12-01
# 2012-12-31 03:00:00           12 2012-12-01
# 2012-12-31 04:00:00           12 2012-12-01
#
# [3559 rows x 7 columns]

# %%
# Transform 'date' column into a date.time type.

df_dt2_2['date'] = pd.to_datetime(df_dt2_2['date'])
df_dt2_2
# Out:
# /var/folders/yq/6pm1lcds6ln5qlsjc5y8fly00000gn/T/ipykernel_4536/2812342474.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt2_2['date'] = pd.to_datetime(df_dt2_2['date'])
#                      count  year     month  day_of_month  week_day  \
# datetime
# 2011-01-01 00:00:00     16  2011   January             1  Saturday
# 2011-01-01 01:00:00     40  2011   January             1  Saturday
# 2011-01-01 02:00:00     32  2011   January             1  Saturday
# 2011-01-01 03:00:00     13  2011   January             1  Saturday
# 2011-01-01 04:00:00      1  2011   January             1  Saturday
# ...                    ...   ...       ...           ...       ...
# 2012-12-31 00:00:00      9  2012  December            31    Monday
# 2012-12-31 01:00:00      5  2012  December            31    Monday
# 2012-12-31 02:00:00      3  2012  December            31    Monday
# 2012-12-31 03:00:00      2  2012  December            31    Monday
# 2012-12-31 04:00:00      2  2012  December            31    Monday
#
#                     month_number       date
# datetime
# 2011-01-01 00:00:00            1 2011-01-01
# 2011-01-01 01:00:00            1 2011-01-01
# 2011-01-01 02:00:00            1 2011-01-01
# 2011-01-01 03:00:00            1 2011-01-01
# 2011-01-01 04:00:00            1 2011-01-01
# ...                          ...        ...
# 2012-12-31 00:00:00           12 2012-12-01
# 2012-12-31 01:00:00           12 2012-12-01
# 2012-12-31 02:00:00           12 2012-12-01
# 2012-12-31 03:00:00           12 2012-12-01
# 2012-12-31 04:00:00           12 2012-12-01
#
# [3559 rows x 7 columns]

# %%
df_dt2_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3559 entries, 2011-01-01 00:00:00 to 2012-12-31 04:00:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   count         3559 non-null   int64
#  1   year          3559 non-null   object
#  2   month         3559 non-null   object
#  3   day_of_month  3559 non-null   int64
#  4   week_day      3559 non-null   object
#  5   month_number  3559 non-null   object
#  6   date          3559 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 222.4+ KB

# %%
# Add a new column only with year and month

df_2['date'] = df_2.index.to_period('M')
df_2
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
# ...                     ...      ...         ...      ...   ...     ...
# 2012-12-31 00:00:00       1        0           1        1  7.38   9.090
# 2012-12-31 01:00:00       1        0           1        1  7.38   9.090
# 2012-12-31 02:00:00       1        0           1        1  6.56   8.335
# 2012-12-31 03:00:00       1        0           1        1  6.56   9.090
# 2012-12-31 04:00:00       1        0           1        1  5.74   8.335
#
#                      humidity  windspeed  casual  registered  ...  \
# datetime                                                      ...
# 2011-01-01 00:00:00        81     0.0000     3.0        13.0  ...
# 2011-01-01 01:00:00        80     0.0000     8.0        32.0  ...
# 2011-01-01 02:00:00        80     0.0000     5.0        27.0  ...
# 2011-01-01 03:00:00        75     0.0000     3.0        10.0  ...
# 2011-01-01 04:00:00        75     0.0000     0.0         1.0  ...
# ...                       ...        ...     ...         ...  ...
# 2012-12-31 00:00:00        55    12.9980     NaN         NaN  ...
# 2012-12-31 01:00:00        55    12.9980     NaN         NaN  ...
# 2012-12-31 02:00:00        59    11.0014     NaN         NaN  ...
# 2012-12-31 03:00:00        59     7.0015     NaN         NaN  ...
# 2012-12-31 04:00:00        69     7.0015     NaN         NaN  ...
#
#                      month_number     month  day_of_month  week_day  hour_day  \
# datetime
# 2011-01-01 00:00:00             1   January             1  Saturday         0
# 2011-01-01 01:00:00             1   January             1  Saturday         1
# 2011-01-01 02:00:00             1   January             1  Saturday         2
# 2011-01-01 03:00:00             1   January             1  Saturday         3
# 2011-01-01 04:00:00             1   January             1  Saturday         4
# ...                           ...       ...           ...       ...       ...
# 2012-12-31 00:00:00            12  December            31    Monday         0
# 2012-12-31 01:00:00            12  December            31    Monday         1
# 2012-12-31 02:00:00            12  December            31    Monday         2
# 2012-12-31 03:00:00            12  December            31    Monday         3
# 2012-12-31 04:00:00            12  December            31    Monday         4
#
#                     season_name  hour_of_day part_of_day  rolling_mean  \
# datetime
# 2011-01-01 00:00:00      winter            0       night           NaN
# 2011-01-01 01:00:00      winter            1       night           NaN
# 2011-01-01 02:00:00      winter            2       night           NaN
# 2011-01-01 03:00:00      winter            3       night           NaN
# 2011-01-01 04:00:00      winter            4       night           NaN
# ...                         ...          ...         ...           ...
# 2012-12-31 00:00:00      winter            0       night       175.458
# 2012-12-31 01:00:00      winter            1       night       175.332
# 2012-12-31 02:00:00      winter            2       night       174.949
# 2012-12-31 03:00:00      winter            3       night       174.288
# 2012-12-31 04:00:00      winter            4       night       174.012
#
#                         date
# datetime
# 2011-01-01 00:00:00  2011-01
# 2011-01-01 01:00:00  2011-01
# 2011-01-01 02:00:00  2011-01
# 2011-01-01 03:00:00  2011-01
# 2011-01-01 04:00:00  2011-01
# ...                      ...
# 2012-12-31 00:00:00  2012-12
# 2012-12-31 01:00:00  2012-12
# 2012-12-31 02:00:00  2012-12
# 2012-12-31 03:00:00  2012-12
# 2012-12-31 04:00:00  2012-12
#
# [3559 rows x 22 columns]

# %%
df_2.pivot_table(values=['count'],
                      columns='week_day',
                      index='date',
                      aggfunc='mean')
# Out:
#               count                                                       \
# week_day     Friday     Monday Saturday     Sunday   Thursday    Tuesday
# date
# 2011-01    7.294118   4.636364    16.16  14.041667   7.714286   4.272727
# 2011-02   10.312500  10.500000    19.80  23.100000   7.470588   4.846154
# 2011-03    8.166667   6.000000    22.10  24.421053   5.260870   5.958333
# 2011-04   15.200000   9.789474    26.20  31.050000  15.850000  11.400000
# 2011-05   23.700000  33.120000    54.75  50.200000  16.100000  11.840000
# 2011-06   21.950000  15.150000    66.80  71.700000  19.840000  13.800000
# 2011-07   27.800000  32.000000    64.44  77.040000  21.300000  17.550000
# 2011-08   21.400000  14.520000    61.80  57.733333  18.400000  13.800000
# 2011-09   20.000000  20.210526    56.75  61.800000  16.125000  11.157895
# 2011-10   23.900000  14.440000    50.68  45.480000  16.850000  11.900000
# 2011-11   18.150000  11.631579    37.25  53.400000  19.550000  10.520000
# 2011-12   15.600000   9.368421    38.60  40.736842  11.520000  10.300000
# 2012-01   13.050000   9.041667    27.60  38.280000   5.700000   6.478261
# 2012-02   16.200000  10.777778    35.05  31.000000  11.000000   8.842105
# 2012-03   17.480000  11.050000    45.24  49.947368  17.640000   8.400000
# 2012-04   23.100000  12.083333    50.55  48.360000  12.600000  10.300000
# 2012-05   32.100000  21.650000    69.85  73.200000  22.240000  15.400000
# 2012-06   32.560000  18.050000    62.72  87.600000  23.550000  16.400000
# 2012-07   30.650000  17.240000    68.15  74.120000  24.400000  18.440000
# 2012-08   28.640000  15.200000    73.90  76.150000  23.320000  16.850000
# 2012-09   28.950000  25.750000    77.36  79.640000  21.900000  12.950000
# 2012-10   26.800000  20.238095    75.00  68.550000  20.850000  13.650000
# 2012-11   20.120000  14.550000    55.15  67.550000  22.260870  13.500000
# 2012-12   16.500000   8.208333    41.12  47.320000  13.200000  12.526316
#
#
# week_day  Wednesday
# date
# 2011-01    4.785714
# 2011-02    5.352941
# 2011-03    5.434783
# 2011-04    8.600000
# 2011-05   11.750000
# 2011-06   17.280000
# 2011-07   18.950000
# 2011-08   16.280000
# 2011-09   12.750000
# 2011-10   14.684211
# 2011-11   10.480000
# 2011-12   10.052632
# 2012-01    6.450000
# 2012-02    9.208333
# 2012-03   11.300000
# 2012-04   13.473684
# 2012-05   15.440000
# 2012-06   21.250000
# 2012-07   35.550000
# 2012-08   20.680000
# 2012-09   16.150000
# 2012-10   17.760000
# 2012-11   34.650000
# 2012-12   12.100000

# %%
pivot_table = df_2.pivot_table(values=['count', 'registered','casual'] ,
                      columns='week_day',
                      aggfunc='mean');

# %%
pivot_table
# Out:
# week_day       Friday     Monday   Saturday     Sunday   Thursday    Tuesday  \
# casual       3.929712   4.490506   8.878788  11.128049   2.550314   2.434084
# count       21.135029  15.367793  49.624762  53.881783  16.687747  11.987830
# registered  16.888179  10.958861  40.981818  44.472561  11.940252   8.675241
#
# week_day    Wednesday
# casual       2.310127
# count       14.788119
# registered  11.898734

# %%
df_2.pivot_table(values=['count', 'registered','casual'] ,
                      columns='week_day',
                      aggfunc='mean').plot(kind='bar');

# %%
df_dt1= df_2

# %% [markdown]
# ## Error Metrics on a naive forecast

# %% [markdown]
# #### With regard to the bikes dataset a ‘naive’ forecast would be to use the count from the year before to predict the next year. Use the count from May 2011 as a forecast for May 2012 and check how far off the predictions are:
#
# #### 1. Filter the dataset for May 2011 and the count column.

# %%
import statsmodels.tools.eval_measures as sm

#y_forecast

y_forecast= df_dt1[['count','year','month','day_of_month']][(df_dt1['month'] == 'May') & (df_dt1['year'] == 2011)]
y_forecast
# Out:
#                      count  year month  day_of_month
# datetime
# 2011-05-01 00:00:00     96  2011   May             1
# 2011-05-01 01:00:00     59  2011   May             1
# 2011-05-01 02:00:00     50  2011   May             1
# 2011-05-01 03:00:00     23  2011   May             1
# 2011-05-01 04:00:00     17  2011   May             1
# ...                    ...   ...   ...           ...
# 2011-05-31 00:00:00     37  2011   May            31
# 2011-05-31 01:00:00     17  2011   May            31
# 2011-05-31 02:00:00     10  2011   May            31
# 2011-05-31 03:00:00      6  2011   May            31
# 2011-05-31 04:00:00      7  2011   May            31
#
# [155 rows x 4 columns]

# %% [markdown]
# #### 2. Filter the dataset for May 2012 and the count column

# %%
# y_actual

y_actual= df_dt1[['count','year','month','day_of_month']][(df_dt1['month'] == 'May') & (df_dt1['year'] == 2012)]
y_actual
# Out:
#                      count  year month  day_of_month
# datetime
# 2012-05-01 00:00:00     35  2012   May             1
# 2012-05-01 01:00:00     21  2012   May             1
# 2012-05-01 02:00:00      8  2012   May             1
# 2012-05-01 03:00:00      3  2012   May             1
# 2012-05-01 04:00:00      8  2012   May             1
# ...                    ...   ...   ...           ...
# 2012-05-31 00:00:00     52  2012   May            31
# 2012-05-31 01:00:00     25  2012   May            31
# 2012-05-31 02:00:00     15  2012   May            31
# 2012-05-31 03:00:00     11  2012   May            31
# 2012-05-31 04:00:00      9  2012   May            31
#
# [155 rows x 4 columns]

# %% [markdown]
# #### 3. Use the above results as the input for sm.rmse(y_forecast, y_actual)

# %%
sm.rmse(y_forecast['count'], y_actual['count'])
# Out:
# 43.6856808311078

# %% [markdown]
# #### 4. How far off on average was this naive prediction?

# %% [markdown]
# ##### This prediction is 168.69 units far from the actual value.

# %% [markdown]
# #### Extra: Forecast vs Actual values plotting

# %%
forecast_day_avg = y_forecast.groupby('day_of_month')['count'].mean()
forecast_df= forecast_day_avg.to_frame()
forecast_df
# Out:
#               count
# day_of_month
# 1              49.0
# 2              71.8
# 3               8.2
# 4               8.4
# 5              10.6
# 6              22.8
# 7              43.8
# 8              52.8
# 9              21.0
# 10              8.8
# 11             14.6
# 12             17.4
# 13             18.4
# 14             55.2
# 15             36.2
# 16             15.0
# 17             12.0
# 18             10.6
# 19             11.8
# 20             17.8
# 21             62.6
# 22             48.8
# 23             15.0
# 24             14.8
# 25             13.4
# 26             24.6
# 27             35.8
# 28             57.4
# 29             64.2
# 30             42.8
# 31             15.4

# %%
actual_day_avg = y_actual.groupby('day_of_month')['count'].mean()
actual_df = actual_day_avg.to_frame()
actual_df
# Out:
#               count
# day_of_month
# 1              15.0
# 2              17.6
# 3              27.8
# 4              33.2
# 5              75.2
# 6              78.4
# 7              11.2
# 8              14.8
# 9              11.4
# 10             10.4
# 11             32.6
# 12             65.6
# 13             62.2
# 14             11.2
# 15             13.2
# 16             17.8
# 17             28.4
# 18             33.0
# 19             73.6
# 20             79.6
# 21             15.8
# 22             17.0
# 23             20.6
# 24             22.2
# 25             29.6
# 26             65.0
# 27             72.6
# 28             48.4
# 29             17.0
# 30              9.8
# 31             22.4

# %%
plt.scatter(forecast_df.index, forecast_df['count'], label='estimate')
plt.scatter(actual_df.index, actual_df['count'], label='actual')
plt.legend();

# %%
import statsmodels.formula.api as sm
from sklearn.metrics import r2_score

# %% [markdown]
# #### 1. Load the data in a pandas dataframe
# #### 2. Set the datetime column as the dataframe index

# %% [markdown]
# #### 3. Subset the dataframe to extract the following columns: temp, atemp, humidity, windspeed and count

# %%
df_dt3 = df_dt1[['temp','atemp','humidity','windspeed','count']]
df_dt3
# Out:
#                      temp   atemp  humidity  windspeed  count
# datetime
# 2011-01-01 00:00:00  9.84  14.395        81     0.0000     16
# 2011-01-01 01:00:00  9.02  13.635        80     0.0000     40
# 2011-01-01 02:00:00  9.02  13.635        80     0.0000     32
# 2011-01-01 03:00:00  9.84  14.395        75     0.0000     13
# 2011-01-01 04:00:00  9.84  14.395        75     0.0000      1
# ...                   ...     ...       ...        ...    ...
# 2012-12-31 00:00:00  7.38   9.090        55    12.9980      9
# 2012-12-31 01:00:00  7.38   9.090        55    12.9980      5
# 2012-12-31 02:00:00  6.56   8.335        59    11.0014      3
# 2012-12-31 03:00:00  6.56   9.090        59     7.0015      2
# 2012-12-31 04:00:00  5.74   8.335        69     7.0015      2
#
# [3559 rows x 5 columns]

# %%
df_dt3.isnull().sum()
# Out:
# temp         0
# atemp        0
# humidity     0
# windspeed    0
# count        0
# dtype: int64

# %%
df_dt3.corr()
# Out:
#                temp     atemp  humidity  windspeed     count
# temp       1.000000  0.987655  0.236138  -0.129717  0.256925
# atemp      0.987655  1.000000  0.241440  -0.179894  0.256369
# humidity   0.236138  0.241440  1.000000  -0.297690 -0.081955
# windspeed -0.129717 -0.179894 -0.297690   1.000000 -0.048325
# count      0.256925  0.256369 -0.081955  -0.048325  1.000000

# %% [markdown]
# #### 4. Generate a heatmap of the subset dataframe. Which of the features has the highest correlation with the count column ?

# %%
sns.heatmap(df_dt3.corr());

# %% [markdown]
# #### 5. Using that feature from step. 4, build a simple linear regression model with count as the response variable. Calculate R2.

# %%
sns.lmplot(x='atemp', y='count', data=df_dt3, ci=None, legend = True);

# %% [markdown]
# #### 5.1 Building a linear regression model using one independent variable:

# %%
model1 = sm.ols(formula='count ~ atemp', data=df_dt3).fit()

# %%
model1.rsquared_adj
# Out:
# 0.06546226997516602

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     250.2
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):           1.60e-54
# Time:                        14:41:12   Log-Likelihood:                -17251.
# No. Observations:                3559   AIC:                         3.451e+04
# Df Residuals:                    3557   BIC:                         3.452e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3526      1.550      2.163      0.031       0.313       6.392
# atemp          1.0484      0.066     15.819      0.000       0.918       1.178
# ==============================================================================
# Omnibus:                     1662.614   Durbin-Watson:                   1.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9349.096
# Skew:                           2.203   Prob(JB):                         0.00
# Kurtosis:                       9.606   Cond. No.                         70.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Assume y is the actual value and f is the predicted values

y = df_dt3['atemp']
f = df_dt3['count']

R_square = r2_score(y, f) 
R_square
# Out:
# -14.948844645421511

# %% [markdown]
# #### 6. Add an additional feature from the subset dataframe and repeat step 5. Observe how the value R2 changed. How can this change be explained ?

# %%
model2 = sm.ols(formula='count ~ atemp + temp', data=df_dt3).fit()

# %%
model2.rsquared_adj
# Out:
# 0.06576407230237324

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     126.2
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):           1.09e-53
# Time:                        14:41:13   Log-Likelihood:                -17250.
# No. Observations:                3559   AIC:                         3.451e+04
# Df Residuals:                    3556   BIC:                         3.452e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.2064      1.656      2.541      0.011       0.960       7.453
# atemp          0.4359      0.423      1.030      0.303      -0.394       1.265
# temp           0.6762      0.461      1.466      0.143      -0.228       1.581
# ==============================================================================
# Omnibus:                     1662.378   Durbin-Watson:                   1.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9358.674
# Skew:                           2.202   Prob(JB):                         0.00
# Kurtosis:                       9.612   Cond. No.                         100.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### The R2 improves a bit because we are adding more variables to explain the variation on the dependent variable.

# %% [markdown]
# #### 7. Add the remaining two features and repeat step 6. Does the model get better when atemp is added as a feature ? why ?

# %%
model3 = sm.ols(formula='count ~ atemp + temp + humidity', data=df_dt3).fit()

# %%
model3.rsquared_adj
# Out:
# 0.08739187613965671

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     114.6
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):           8.05e-71
# Time:                        14:41:13   Log-Likelihood:                -17208.
# No. Observations:                3559   AIC:                         3.442e+04
# Df Residuals:                    3555   BIC:                         3.445e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     22.5295      2.572      8.760      0.000      17.487      27.572
# atemp          0.6447      0.419      1.540      0.124      -0.176       1.466
# temp           0.6119      0.456      1.342      0.180      -0.282       1.506
# humidity      -0.3032      0.033     -9.234      0.000      -0.368      -0.239
# ==============================================================================
# Omnibus:                     1632.523   Durbin-Watson:                   1.104
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9009.990
# Skew:                           2.162   Prob(JB):                         0.00
# Kurtosis:                       9.486   Cond. No.                         398.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model4 = sm.ols(formula='count ~ atemp + temp + humidity + windspeed', data=df_dt3).fit()

# %%
model4.rsquared_adj
# Out:
# 0.08993645542070194

# %%
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     88.90
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):           4.11e-72
# Time:                        14:41:13   Log-Likelihood:                -17202.
# No. Observations:                3559   AIC:                         3.441e+04
# Df Residuals:                    3554   BIC:                         3.445e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     28.6458      3.165      9.051      0.000      22.441      34.851
# atemp          0.1581      0.443      0.357      0.721      -0.711       1.027
# temp           1.1183      0.480      2.328      0.020       0.176       2.060
# humidity      -0.3342      0.034     -9.800      0.000      -0.401      -0.267
# windspeed     -0.2517      0.076     -3.308      0.001      -0.401      -0.102
# ==============================================================================
# Omnibus:                     1626.124   Durbin-Watson:                   1.110
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8952.651
# Skew:                           2.153   Prob(JB):                         0.00
# Kurtosis:                       9.468   Cond. No.                         495.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model5 = sm.ols(formula='count ~ temp + humidity + windspeed', data=df_dt3).fit()

# %%
model5.rsquared_adj
# Out:
# 0.09015987985573204

# %%
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     118.5
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):           3.69e-73
# Time:                        14:41:13   Log-Likelihood:                -17202.
# No. Observations:                3559   AIC:                         3.441e+04
# Df Residuals:                    3555   BIC:                         3.444e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.0954      2.903     10.024      0.000      23.404      34.786
# temp           1.2877      0.074     17.511      0.000       1.143       1.432
# humidity      -0.3347      0.034     -9.826      0.000      -0.402      -0.268
# windspeed     -0.2607      0.072     -3.632      0.000      -0.401      -0.120
# ==============================================================================
# Omnibus:                     1626.170   Durbin-Watson:                   1.110
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8953.942
# Skew:                           2.153   Prob(JB):                         0.00
# Kurtosis:                       9.469   Cond. No.                         435.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### The model gets better because we are including more independent variables to explain the variation of the dependent variable.

# %% [markdown]
# #### 8. What additional features can be added to improve the fit of the model ?

# %%
# Adding the columns 'casual' and 'registered' to the data frame.

df_dt4 = df_dt1[['temp','atemp','humidity','windspeed','count', 'casual','registered']]
df_dt4
# Out:
#                      temp   atemp  humidity  windspeed  count  casual  \
# datetime
# 2011-01-01 00:00:00  9.84  14.395        81     0.0000     16     3.0
# 2011-01-01 01:00:00  9.02  13.635        80     0.0000     40     8.0
# 2011-01-01 02:00:00  9.02  13.635        80     0.0000     32     5.0
# 2011-01-01 03:00:00  9.84  14.395        75     0.0000     13     3.0
# 2011-01-01 04:00:00  9.84  14.395        75     0.0000      1     0.0
# ...                   ...     ...       ...        ...    ...     ...
# 2012-12-31 00:00:00  7.38   9.090        55    12.9980      9     NaN
# 2012-12-31 01:00:00  7.38   9.090        55    12.9980      5     NaN
# 2012-12-31 02:00:00  6.56   8.335        59    11.0014      3     NaN
# 2012-12-31 03:00:00  6.56   9.090        59     7.0015      2     NaN
# 2012-12-31 04:00:00  5.74   8.335        69     7.0015      2     NaN
#
#                      registered
# datetime
# 2011-01-01 00:00:00        13.0
# 2011-01-01 01:00:00        32.0
# 2011-01-01 02:00:00        27.0
# 2011-01-01 03:00:00        10.0
# 2011-01-01 04:00:00         1.0
# ...                         ...
# 2012-12-31 00:00:00         NaN
# 2012-12-31 01:00:00         NaN
# 2012-12-31 02:00:00         NaN
# 2012-12-31 03:00:00         NaN
# 2012-12-31 04:00:00         NaN
#
# [3559 rows x 7 columns]

# %%
df_dt4.corr()
# Out:
#                 temp     atemp  humidity  windspeed     count    casual  \
# temp        1.000000  0.987655  0.236138  -0.129717  0.256925  0.325805
# atemp       0.987655  1.000000  0.241440  -0.179894  0.256369  0.322288
# humidity    0.236138  0.241440  1.000000  -0.297690 -0.081955 -0.027604
# windspeed  -0.129717 -0.179894 -0.297690   1.000000 -0.048325 -0.075638
# count       0.256925  0.256369 -0.081955  -0.048325  1.000000  0.861239
# casual      0.325805  0.322288 -0.027604  -0.075638  0.861239  1.000000
# registered  0.195215  0.193180 -0.065030  -0.060214  0.989558  0.778997
#
#             registered
# temp          0.195215
# atemp         0.193180
# humidity     -0.065030
# windspeed    -0.060214
# count         0.989558
# casual        0.778997
# registered    1.000000

# %%
sns.heatmap(df_dt4.corr());

# %%
sns.lmplot(x='registered', y='count', data=df_dt4, ci=None, legend = True);

# %%
model6 = sm.ols(formula='count ~ registered', data=df_dt4).fit()

# %%
model6.rsquared_adj
# Out:
# 0.9792164143593686

# %%
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.979
# Method:                 Least Squares   F-statistic:                 1.051e+05
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:14   Log-Likelihood:                -6656.2
# No. Observations:                2232   AIC:                         1.332e+04
# Df Residuals:                    2230   BIC:                         1.333e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5007      0.129      3.894      0.000       0.249       0.753
# registered     1.2209      0.004    324.213      0.000       1.214       1.228
# ==============================================================================
# Omnibus:                     1072.859   Durbin-Watson:                   1.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15263.157
# Skew:                           1.901   Prob(JB):                         0.00
# Kurtosis:                      15.234   Cond. No.                         43.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.lmplot(x='casual', y='count', data=df_dt4, ci=None, legend = True);

# %%
model7 = sm.ols(formula='count ~ casual', data=df_dt4).fit()

# %%
model7.rsquared_adj
# Out:
# 0.7416161844793203

# %%
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.742
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     6404.
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:14   Log-Likelihood:                -9468.8
# No. Observations:                2232   AIC:                         1.894e+04
# Df Residuals:                    2230   BIC:                         1.895e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.9238      0.431     16.075      0.000       6.079       7.769
# casual         3.7467      0.047     80.028      0.000       3.655       3.838
# ==============================================================================
# Omnibus:                      682.880   Durbin-Watson:                   1.224
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4724.654
# Skew:                           1.261   Prob(JB):                         0.00
# Kurtosis:                       9.667   Cond. No.                         11.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# #### By including 'Registered' variable as a predictor of 'count' the model fit significantly improves (model6- rsquared_adj= 0.9792164143593686 vs model7 'casual' independent variable- rsquared_adj=0.7416161844793203).

# %% [markdown]
# ## Now let's see what other variables together with 'Registered' make the model even better.

# %%
model8 = sm.ols(formula='count ~ registered + temp ', data=df_dt4).fit()

# %%
model8.rsquared_adj
# Out:
# 0.9808666158134562

# %%
model8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 5.719e+04
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:14   Log-Likelihood:                -6563.3
# No. Observations:                2232   AIC:                         1.313e+04
# Df Residuals:                    2229   BIC:                         1.315e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.8694      0.272    -10.550      0.000      -3.403      -2.336
# registered     1.2109      0.004    328.690      0.000       1.204       1.218
# temp           0.1934      0.014     13.904      0.000       0.166       0.221
# ==============================================================================
# Omnibus:                     1114.121   Durbin-Watson:                   1.335
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17779.015
# Skew:                           1.960   Prob(JB):                         0.00
# Kurtosis:                      16.259   Cond. No.                         103.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model9 = sm.ols(formula='count ~ registered + atemp', data=df_dt4).fit()

# %%
model9.rsquared_adj
# Out:
# 0.9808285737112846

# %% [markdown]
# #### Conclusion:
#
# #### By adding individually the variables 'temp' (model8) and 'atemp' (model9) to the 'registered' variable together in one model, 'temp' variable has a higher impact on making the model fit better.
#
# #### model6 (only 'registered' variable) = 0.9792164143593686
# #### model8 rsquared_adj = 0.9808666158134562
# #### model9 rsquared_adj =0.9808285737112846

# %% [markdown]
# ### Now let's see what other variables together with "registered" and "temp" make the model even better.

# %%
model10 = sm.ols(formula='count ~ registered + temp + atemp', data=df_dt4).fit()

# %%
model10.rsquared_adj
# Out:
# 0.9808586873981621

# %%
model8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 5.719e+04
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:14   Log-Likelihood:                -6563.3
# No. Observations:                2232   AIC:                         1.313e+04
# Df Residuals:                    2229   BIC:                         1.315e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.8694      0.272    -10.550      0.000      -3.403      -2.336
# registered     1.2109      0.004    328.690      0.000       1.204       1.218
# temp           0.1934      0.014     13.904      0.000       0.166       0.221
# ==============================================================================
# Omnibus:                     1114.121   Durbin-Watson:                   1.335
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17779.015
# Skew:                           1.960   Prob(JB):                         0.00
# Kurtosis:                      16.259   Cond. No.                         103.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Including 'humidity'

model11 = sm.ols(formula='count ~ registered + temp + humidity', data=df_dt4).fit()

# %%
model11.rsquared_adj
# Out:
# 0.9808746511816533

# %%
model11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 3.814e+04
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:14   Log-Likelihood:                -6562.4
# No. Observations:                2232   AIC:                         1.313e+04
# Df Residuals:                    2228   BIC:                         1.316e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.3250      0.476     -4.880      0.000      -3.259      -1.391
# registered     1.2104      0.004    326.587      0.000       1.203       1.218
# temp           0.1979      0.014     13.859      0.000       0.170       0.226
# humidity      -0.0087      0.006     -1.392      0.164      -0.021       0.004
# ==============================================================================
# Omnibus:                     1121.244   Durbin-Watson:                   1.336
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18112.626
# Skew:                           1.973   Prob(JB):                         0.00
# Kurtosis:                      16.386   Cond. No.                         383.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Including 'windspeed'
model12 = sm.ols(formula='count ~ registered + temp + windspeed', data=df_dt4).fit()

# %%
model12.rsquared_adj
# Out:
# 0.980867246871164

# %%
model12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 3.813e+04
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:15   Log-Likelihood:                -6562.8
# No. Observations:                2232   AIC:                         1.313e+04
# Df Residuals:                    2228   BIC:                         1.316e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.7005      0.317     -8.516      0.000      -3.322      -2.079
# registered     1.2108      0.004    328.361      0.000       1.204       1.218
# temp           0.1921      0.014     13.759      0.000       0.165       0.219
# windspeed     -0.0136      0.013     -1.036      0.300      -0.039       0.012
# ==============================================================================
# Omnibus:                     1112.293   Durbin-Watson:                   1.336
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17731.580
# Skew:                           1.956   Prob(JB):                         0.00
# Kurtosis:                      16.242   Cond. No.                         123.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Conclusion: By adding 'humidty' to the current model with 2 independent variables 'registered' and 'temp'(model8 rsquared_adj = 0.9808666158134562), the model fit registers a slight improvement than the other two variables (model11- rsquared= 0.9548637017042095).
#
#
# #### model10=  Independent variables: registered + temp + atemp - rsquared_adj = 0.9808586873981621
# #### model11=  Independent variables: registered + temp + humidity - rsquared_adj = 0.9808746511816533
# #### model12 rsquared_adj = Independent variables: registered + temp + windspeed - rsquared_adj = 0.980867246871164

# %% [markdown]
# ### Now let's see what other variables together with 'registered' + 'temp' + 'humidity' make the model even better.

# %%
#Including 'atemp'

model13 = sm.ols(formula='count ~ registered + temp + humidity + atemp', data=df_dt4).fit()

# %%
model13.rsquared_adj
# Out:
# 0.9808674043606399

# %%
model13.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 2.860e+04
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:15   Log-Likelihood:                -6562.3
# No. Observations:                2232   AIC:                         1.313e+04
# Df Residuals:                    2227   BIC:                         1.316e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.3708      0.490     -4.834      0.000      -3.333      -1.409
# registered     1.2103      0.004    326.488      0.000       1.203       1.218
# temp           0.1665      0.081      2.061      0.039       0.008       0.325
# humidity      -0.0089      0.006     -1.420      0.156      -0.021       0.003
# atemp          0.0293      0.074      0.395      0.693      -0.116       0.175
# ==============================================================================
# Omnibus:                     1121.818   Durbin-Watson:                   1.337
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18155.775
# Skew:                           1.974   Prob(JB):                         0.00
# Kurtosis:                      16.403   Cond. No.                         410.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Including 'windspeed'

model14 = sm.ols(formula='count ~ registered + temp + humidity + windspeed', data=df_dt4).fit()

# %%
model14.rsquared_adj
# Out:
# 0.980885953448357

# %%
model14.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 2.862e+04
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:15   Log-Likelihood:                -6561.2
# No. Observations:                2232   AIC:                         1.313e+04
# Df Residuals:                    2227   BIC:                         1.316e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.8785      0.559     -3.358      0.001      -2.975      -0.782
# registered     1.2099      0.004    325.562      0.000       1.203       1.217
# temp           0.1975      0.014     13.831      0.000       0.169       0.225
# humidity      -0.0117      0.007     -1.783      0.075      -0.025       0.001
# windspeed     -0.0209      0.014     -1.522      0.128      -0.048       0.006
# ==============================================================================
# Omnibus:                     1120.827   Durbin-Watson:                   1.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18152.905
# Skew:                           1.971   Prob(JB):                         0.00
# Kurtosis:                      16.403   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Conclusion: By adding 'atemp' to the current model with 3 independent variables 'registered' + 'temp' + 'humidity' (model11 rsquared_adj = 0.9808746511816533), the model fit registers a slight improvement than the model with the variable 'windspeed' (model13- rsquared= 0.9808674043606399).
#
#
# #### model13=  Independent variables: registered + temp + humidity + atemp - rsquared_adj = 0.9808674043606399
# #### model14 rsquared_adj = Independent variables: registered + temp + humidity + windspeed - rsquared_adj = 0.980885953448357

# %% [markdown]
# ### Now let's see what happens when all the independent variables are included: 'registered' + 'temp' + 'humidity' + 'atemp' + 'windspeed':

# %%
#Including 'windspeed'

model15 = sm.ols(formula='count ~ registered + temp + humidity + windspeed', data=df_dt4).fit()

# %%
model15.rsquared
# Out:
# 0.9809202233659754

# %%
model15.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                 2.862e+04
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:15   Log-Likelihood:                -6561.2
# No. Observations:                2232   AIC:                         1.313e+04
# Df Residuals:                    2227   BIC:                         1.316e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.8785      0.559     -3.358      0.001      -2.975      -0.782
# registered     1.2099      0.004    325.562      0.000       1.203       1.217
# temp           0.1975      0.014     13.831      0.000       0.169       0.225
# humidity      -0.0117      0.007     -1.783      0.075      -0.025       0.001
# windspeed     -0.0209      0.014     -1.522      0.128      -0.048       0.006
# ==============================================================================
# Omnibus:                     1120.827   Durbin-Watson:                   1.338
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18152.905
# Skew:                           1.971   Prob(JB):                         0.00
# Kurtosis:                      16.403   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Conclusion:
#
#
# #### model13=  Independent variables: registered + temp + humidity + atemp - rsquared_adj = 0.9808674043606399
#
# #### vs
#
# #### model15 (including all the 5 independent variables)=  Independent variables: registered + temp + humidity + atemp + windspeed - rsquared_adj = 0.9809202233659754
#
# #### By including the extra variable 'windspeed', the rsquared_adj does not improve.

# %%
df_dt1
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
# ...                     ...      ...         ...      ...   ...     ...
# 2012-12-31 00:00:00       1        0           1        1  7.38   9.090
# 2012-12-31 01:00:00       1        0           1        1  7.38   9.090
# 2012-12-31 02:00:00       1        0           1        1  6.56   8.335
# 2012-12-31 03:00:00       1        0           1        1  6.56   9.090
# 2012-12-31 04:00:00       1        0           1        1  5.74   8.335
#
#                      humidity  windspeed  casual  registered  ...  \
# datetime                                                      ...
# 2011-01-01 00:00:00        81     0.0000     3.0        13.0  ...
# 2011-01-01 01:00:00        80     0.0000     8.0        32.0  ...
# 2011-01-01 02:00:00        80     0.0000     5.0        27.0  ...
# 2011-01-01 03:00:00        75     0.0000     3.0        10.0  ...
# 2011-01-01 04:00:00        75     0.0000     0.0         1.0  ...
# ...                       ...        ...     ...         ...  ...
# 2012-12-31 00:00:00        55    12.9980     NaN         NaN  ...
# 2012-12-31 01:00:00        55    12.9980     NaN         NaN  ...
# 2012-12-31 02:00:00        59    11.0014     NaN         NaN  ...
# 2012-12-31 03:00:00        59     7.0015     NaN         NaN  ...
# 2012-12-31 04:00:00        69     7.0015     NaN         NaN  ...
#
#                      month_number     month  day_of_month  week_day  hour_day  \
# datetime
# 2011-01-01 00:00:00             1   January             1  Saturday         0
# 2011-01-01 01:00:00             1   January             1  Saturday         1
# 2011-01-01 02:00:00             1   January             1  Saturday         2
# 2011-01-01 03:00:00             1   January             1  Saturday         3
# 2011-01-01 04:00:00             1   January             1  Saturday         4
# ...                           ...       ...           ...       ...       ...
# 2012-12-31 00:00:00            12  December            31    Monday         0
# 2012-12-31 01:00:00            12  December            31    Monday         1
# 2012-12-31 02:00:00            12  December            31    Monday         2
# 2012-12-31 03:00:00            12  December            31    Monday         3
# 2012-12-31 04:00:00            12  December            31    Monday         4
#
#                     season_name  hour_of_day part_of_day  rolling_mean  \
# datetime
# 2011-01-01 00:00:00      winter            0       night           NaN
# 2011-01-01 01:00:00      winter            1       night           NaN
# 2011-01-01 02:00:00      winter            2       night           NaN
# 2011-01-01 03:00:00      winter            3       night           NaN
# 2011-01-01 04:00:00      winter            4       night           NaN
# ...                         ...          ...         ...           ...
# 2012-12-31 00:00:00      winter            0       night       175.458
# 2012-12-31 01:00:00      winter            1       night       175.332
# 2012-12-31 02:00:00      winter            2       night       174.949
# 2012-12-31 03:00:00      winter            3       night       174.288
# 2012-12-31 04:00:00      winter            4       night       174.012
#
#                         date
# datetime
# 2011-01-01 00:00:00  2011-01
# 2011-01-01 01:00:00  2011-01
# 2011-01-01 02:00:00  2011-01
# 2011-01-01 03:00:00  2011-01
# 2011-01-01 04:00:00  2011-01
# ...                      ...
# 2012-12-31 00:00:00  2012-12
# 2012-12-31 01:00:00  2012-12
# 2012-12-31 02:00:00  2012-12
# 2012-12-31 03:00:00  2012-12
# 2012-12-31 04:00:00  2012-12
#
# [3559 rows x 22 columns]

# %%
df_dt1['season'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df_dt1['month_number'].replace({1:8, 2:9, 3:10, 4:11, 5:12,6:1, 7:2, 8:3, 9:4, 10:5,11:6,12:7},inplace = True)

# %%
df_dt1
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
# ...                     ...      ...         ...      ...   ...     ...
# 2012-12-31 00:00:00       1        0           1        1  7.38   9.090
# 2012-12-31 01:00:00       1        0           1        1  7.38   9.090
# 2012-12-31 02:00:00       1        0           1        1  6.56   8.335
# 2012-12-31 03:00:00       1        0           1        1  6.56   9.090
# 2012-12-31 04:00:00       1        0           1        1  5.74   8.335
#
#                      humidity  windspeed  casual  registered  ...  \
# datetime                                                      ...
# 2011-01-01 00:00:00        81     0.0000     3.0        13.0  ...
# 2011-01-01 01:00:00        80     0.0000     8.0        32.0  ...
# 2011-01-01 02:00:00        80     0.0000     5.0        27.0  ...
# 2011-01-01 03:00:00        75     0.0000     3.0        10.0  ...
# 2011-01-01 04:00:00        75     0.0000     0.0         1.0  ...
# ...                       ...        ...     ...         ...  ...
# 2012-12-31 00:00:00        55    12.9980     NaN         NaN  ...
# 2012-12-31 01:00:00        55    12.9980     NaN         NaN  ...
# 2012-12-31 02:00:00        59    11.0014     NaN         NaN  ...
# 2012-12-31 03:00:00        59     7.0015     NaN         NaN  ...
# 2012-12-31 04:00:00        69     7.0015     NaN         NaN  ...
#
#                      month_number     month  day_of_month  week_day  hour_day  \
# datetime
# 2011-01-01 00:00:00             8   January             1  Saturday         0
# 2011-01-01 01:00:00             8   January             1  Saturday         1
# 2011-01-01 02:00:00             8   January             1  Saturday         2
# 2011-01-01 03:00:00             8   January             1  Saturday         3
# 2011-01-01 04:00:00             8   January             1  Saturday         4
# ...                           ...       ...           ...       ...       ...
# 2012-12-31 00:00:00             7  December            31    Monday         0
# 2012-12-31 01:00:00             7  December            31    Monday         1
# 2012-12-31 02:00:00             7  December            31    Monday         2
# 2012-12-31 03:00:00             7  December            31    Monday         3
# 2012-12-31 04:00:00             7  December            31    Monday         4
#
#                     season_name  hour_of_day part_of_day  rolling_mean  \
# datetime
# 2011-01-01 00:00:00      winter            0       night           NaN
# 2011-01-01 01:00:00      winter            1       night           NaN
# 2011-01-01 02:00:00      winter            2       night           NaN
# 2011-01-01 03:00:00      winter            3       night           NaN
# 2011-01-01 04:00:00      winter            4       night           NaN
# ...                         ...          ...         ...           ...
# 2012-12-31 00:00:00      winter            0       night       175.458
# 2012-12-31 01:00:00      winter            1       night       175.332
# 2012-12-31 02:00:00      winter            2       night       174.949
# 2012-12-31 03:00:00      winter            3       night       174.288
# 2012-12-31 04:00:00      winter            4       night       174.012
#
#                         date
# datetime
# 2011-01-01 00:00:00  2011-01
# 2011-01-01 01:00:00  2011-01
# 2011-01-01 02:00:00  2011-01
# 2011-01-01 03:00:00  2011-01
# 2011-01-01 04:00:00  2011-01
# ...                      ...
# 2012-12-31 00:00:00  2012-12
# 2012-12-31 01:00:00  2012-12
# 2012-12-31 02:00:00  2012-12
# 2012-12-31 03:00:00  2012-12
# 2012-12-31 04:00:00  2012-12
#
# [3559 rows x 22 columns]

# %%
season_labels = ['summer', 'autumn', 'winter','spring']
bin_boundaries = [0.9, 3, 6,9, 12.1]

#time_labels = ['evening_2','morning', 'afternoon', 'evening']
#bin_boundaries = [-0.1, 4.9, 12, 18, 23.9]

# %%
pd.cut(df_dt1['month_number'], bins=bin_boundaries, labels=season_labels).sample(23)
# Out:
# datetime
# 2011-12-11 02:00:00    winter
# 2011-06-19 02:00:00    summer
# 2012-10-27 00:00:00    autumn
# 2012-08-20 02:00:00    summer
# 2011-05-21 00:00:00    spring
# 2011-02-05 00:00:00    winter
# 2012-05-13 01:00:00    spring
# 2012-05-05 03:00:00    spring
# 2011-06-19 00:00:00    summer
# 2011-05-28 04:00:00    spring
# 2011-08-10 03:00:00    summer
# 2012-11-29 00:00:00    autumn
# 2011-08-31 00:00:00    summer
# 2011-01-25 02:00:00    winter
# 2012-03-31 01:00:00    spring
# 2012-09-05 02:00:00    autumn
# 2012-03-15 00:00:00    spring
# 2011-02-13 01:00:00    winter
# 2012-09-23 01:00:00    autumn
# 2011-09-29 00:00:00    autumn
# 2011-01-10 03:00:00    winter
# 2012-09-06 03:00:00    autumn
# 2012-12-26 03:00:00    winter
# Name: month_number, dtype: category
# Categories (4, object): ['summer' < 'autumn' < 'winter' < 'spring']

# %%
#General Model:

model5 = sm.ols(formula='count ~ temp + humidity + windspeed', data=df_dt1).fit()

# %%
model5.rsquared_adj
# Out:
# 0.09015987985573204

# %%
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     118.5
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):           3.69e-73
# Time:                        14:41:15   Log-Likelihood:                -17202.
# No. Observations:                3559   AIC:                         3.441e+04
# Df Residuals:                    3555   BIC:                         3.444e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.0954      2.903     10.024      0.000      23.404      34.786
# temp           1.2877      0.074     17.511      0.000       1.143       1.432
# humidity      -0.3347      0.034     -9.826      0.000      -0.402      -0.268
# windspeed     -0.2607      0.072     -3.632      0.000      -0.401      -0.120
# ==============================================================================
# Omnibus:                     1626.170   Durbin-Watson:                   1.110
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8953.942
# Skew:                           2.153   Prob(JB):                         0.00
# Kurtosis:                       9.469   Cond. No.                         435.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model16 = sm.ols(formula='count ~ temp + humidity + windspeed + season', data=df_dt1).fit()

# %%
model16.rsquared_adj
# Out:
# 0.10408558979650495

# %%
model16.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     104.3
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):           3.83e-84
# Time:                        14:41:15   Log-Likelihood:                -17174.
# No. Observations:                3559   AIC:                         3.436e+04
# Df Residuals:                    3554   BIC:                         3.439e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     24.5786      2.943      8.353      0.000      18.809      30.348
# temp           1.1385      0.076     15.053      0.000       0.990       1.287
# humidity      -0.3707      0.034    -10.858      0.000      -0.438      -0.304
# windspeed     -0.2064      0.072     -2.883      0.004      -0.347      -0.066
# season         3.6984      0.493      7.500      0.000       2.732       4.665
# ==============================================================================
# Omnibus:                     1588.508   Durbin-Watson:                   1.126
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8426.728
# Skew:                           2.108   Prob(JB):                         0.00
# Kurtosis:                       9.249   Cond. No.                         445.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model17 = sm.ols(formula='count ~ temp + humidity + windspeed + holiday', data=df_dt1).fit()

# %%
model17.rsquared_adj
# Out:
# 0.09119325871301465

# %%
model17.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     90.26
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):           3.57e-73
# Time:                        14:41:15   Log-Likelihood:                -17200.
# No. Observations:                3559   AIC:                         3.441e+04
# Df Residuals:                    3554   BIC:                         3.444e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     28.8035      2.904      9.919      0.000      23.110      34.497
# temp           1.2922      0.074     17.575      0.000       1.148       1.436
# humidity      -0.3344      0.034     -9.821      0.000      -0.401      -0.268
# windspeed     -0.2619      0.072     -3.651      0.000      -0.403      -0.121
# holiday        6.8952      3.071      2.246      0.025       0.875      12.916
# ==============================================================================
# Omnibus:                     1629.822   Durbin-Watson:                   1.109
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9021.177
# Skew:                           2.156   Prob(JB):                         0.00
# Kurtosis:                       9.499   Cond. No.                         464.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model18 = sm.ols(formula='count ~ temp + humidity + windspeed + workingday', data=df_dt1).fit()

# %%
model18.rsquared_adj
# Out:
# 0.3578043164261987

# %%
model18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.358
# Method:                 Least Squares   F-statistic:                     496.6
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:15   Log-Likelihood:                -16582.
# No. Observations:                3559   AIC:                         3.317e+04
# Df Residuals:                    3554   BIC:                         3.320e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     45.7802      2.477     18.483      0.000      40.924      50.636
# temp           1.4137      0.062     22.850      0.000       1.292       1.535
# humidity      -0.2649      0.029     -9.236      0.000      -0.321      -0.209
# windspeed     -0.2549      0.060     -4.228      0.000      -0.373      -0.137
# workingday   -35.4985      0.922    -38.505      0.000     -37.306     -33.691
# ==============================================================================
# Omnibus:                     1464.165   Durbin-Watson:                   1.461
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12120.505
# Skew:                           1.742   Prob(JB):                         0.00
# Kurtosis:                      11.342   Cond. No.                         443.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model19 = sm.ols(formula='count ~ temp + humidity + windspeed + weather', data=df_dt1).fit()

# %%
model19.rsquared_adj
# Out:
# 0.09144674859558122

# %%
model18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.358
# Method:                 Least Squares   F-statistic:                     496.6
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):               0.00
# Time:                        14:41:16   Log-Likelihood:                -16582.
# No. Observations:                3559   AIC:                         3.317e+04
# Df Residuals:                    3554   BIC:                         3.320e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     45.7802      2.477     18.483      0.000      40.924      50.636
# temp           1.4137      0.062     22.850      0.000       1.292       1.535
# humidity      -0.2649      0.029     -9.236      0.000      -0.321      -0.209
# windspeed     -0.2549      0.060     -4.228      0.000      -0.373      -0.137
# workingday   -35.4985      0.922    -38.505      0.000     -37.306     -33.691
# ==============================================================================
# Omnibus:                     1464.165   Durbin-Watson:                   1.461
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12120.505
# Skew:                           1.742   Prob(JB):                         0.00
# Kurtosis:                      11.342   Cond. No.                         443.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df_dt1
june1_df = df_dt1.loc['2011-06-01']

# %% [markdown]
# #### 2. Using sns.displot() plot the distribution of the count during that day (Try setting the parameter kde=True). More info on this plotting function here: displot

# %%
sns.displot(june1_df['count'], kde=True, stat="probability");

# %% [markdown]
# #### 3. Filter bike data for the year 2011

# %%
year2011_df = df_dt1.loc['2011']

# %% [markdown]
# #### 4. Again using sns.displot() plot the distribution of the temperature of the entire year.

# %%
sns.displot(year2011_df['temp'], kde=True, stat="probability");

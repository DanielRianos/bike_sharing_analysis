# %% [markdown]
# # Data Wrangling

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_dt1 = pd.read_csv('data_sets/dc_bikes_2.csv', index_col=0)
df_dt1.index = pd.to_datetime(df_dt1.index)

# %%
df_dt1.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#                      humidity  windspeed  casual  registered  count  year  \
# datetime
# 2011-01-01 00:00:00        81        0.0     3.0        13.0     16  2011
# 2011-01-01 01:00:00        80        0.0     8.0        32.0     40  2011
# 2011-01-01 02:00:00        80        0.0     5.0        27.0     32  2011
# 2011-01-01 03:00:00        75        0.0     3.0        10.0     13  2011
# 2011-01-01 04:00:00        75        0.0     0.0         1.0      1  2011
#
#                      month_number    month  day_of_month  week_day  hour_day  \
# datetime
# 2011-01-01 00:00:00             1  January             1  Saturday         0
# 2011-01-01 01:00:00             1  January             1  Saturday         1
# 2011-01-01 02:00:00             1  January             1  Saturday         2
# 2011-01-01 03:00:00             1  January             1  Saturday         3
# 2011-01-01 04:00:00             1  January             1  Saturday         4
#
#                     season_name  hour_of_day part_of_day
# datetime
# 2011-01-01 00:00:00      winter            0       night
# 2011-01-01 01:00:00      winter            1       night
# 2011-01-01 02:00:00      winter            2       night
# 2011-01-01 03:00:00      winter            3       night
# 2011-01-01 04:00:00      winter            4       night

# %%
# Drop option to reduce the table

df_dt2 = df_dt1.drop(['season', 'holiday','workingday','weather','temp','atemp','humidity','windspeed','casual','registered','hour_day','part_of_day'], axis=1)
df_dt2
# Out:
#                      count  year  month_number     month  day_of_month  \
# datetime
# 2011-01-01 00:00:00     16  2011             1   January             1
# 2011-01-01 01:00:00     40  2011             1   January             1
# 2011-01-01 02:00:00     32  2011             1   January             1
# 2011-01-01 03:00:00     13  2011             1   January             1
# 2011-01-01 04:00:00      1  2011             1   January             1
# ...                    ...   ...           ...       ...           ...
# 2012-12-31 19:00:00    156  2012            12  December            31
# 2012-12-31 20:00:00    104  2012            12  December            31
# 2012-12-31 21:00:00     67  2012            12  December            31
# 2012-12-31 22:00:00     43  2012            12  December            31
# 2012-12-31 23:00:00     28  2012            12  December            31
#
#                      week_day season_name  hour_of_day
# datetime
# 2011-01-01 00:00:00  Saturday      winter            0
# 2011-01-01 01:00:00  Saturday      winter            1
# 2011-01-01 02:00:00  Saturday      winter            2
# 2011-01-01 03:00:00  Saturday      winter            3
# 2011-01-01 04:00:00  Saturday      winter            4
# ...                       ...         ...          ...
# 2012-12-31 19:00:00    Monday      winter           19
# 2012-12-31 20:00:00    Monday      winter           20
# 2012-12-31 21:00:00    Monday      winter           21
# 2012-12-31 22:00:00    Monday      winter           22
# 2012-12-31 23:00:00    Monday      winter           23
#
# [17379 rows x 8 columns]

# %%
# Selecting columns option to reduce the table

df_dt2_2= df_dt1[['count','year','month','day_of_month','week_day','month_number']]
df_dt2_2
# Out:
#                      count  year     month  day_of_month  week_day  \
# datetime
# 2011-01-01 00:00:00     16  2011   January             1  Saturday
# 2011-01-01 01:00:00     40  2011   January             1  Saturday
# 2011-01-01 02:00:00     32  2011   January             1  Saturday
# 2011-01-01 03:00:00     13  2011   January             1  Saturday
# 2011-01-01 04:00:00      1  2011   January             1  Saturday
# ...                    ...   ...       ...           ...       ...
# 2012-12-31 19:00:00    156  2012  December            31    Monday
# 2012-12-31 20:00:00    104  2012  December            31    Monday
# 2012-12-31 21:00:00     67  2012  December            31    Monday
# 2012-12-31 22:00:00     43  2012  December            31    Monday
# 2012-12-31 23:00:00     28  2012  December            31    Monday
#
#                      month_number
# datetime
# 2011-01-01 00:00:00             1
# 2011-01-01 01:00:00             1
# 2011-01-01 02:00:00             1
# 2011-01-01 03:00:00             1
# 2011-01-01 04:00:00             1
# ...                           ...
# 2012-12-31 19:00:00            12
# 2012-12-31 20:00:00            12
# 2012-12-31 21:00:00            12
# 2012-12-31 22:00:00            12
# 2012-12-31 23:00:00            12
#
# [17379 rows x 6 columns]

# %%
df_dt2_2.head()
# Out:
#                      count  year    month  day_of_month  week_day  \
# datetime
# 2011-01-01 00:00:00     16  2011  January             1  Saturday
# 2011-01-01 01:00:00     40  2011  January             1  Saturday
# 2011-01-01 02:00:00     32  2011  January             1  Saturday
# 2011-01-01 03:00:00     13  2011  January             1  Saturday
# 2011-01-01 04:00:00      1  2011  January             1  Saturday
#
#                      month_number
# datetime
# 2011-01-01 00:00:00             1
# 2011-01-01 01:00:00             1
# 2011-01-01 02:00:00             1
# 2011-01-01 03:00:00             1
# 2011-01-01 04:00:00             1

# %%
# Transform 'year' column type from 'int' to 'str' to later concatinate.

df_dt2_2['year']= df_dt2_2['year'].astype(str)
# Out:
# /var/folders/yq/6pm1lcds6ln5qlsjc5y8fly00000gn/T/ipykernel_10299/303696026.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt2_2['year']= df_dt2_2['year'].astype(str)

# %%
df_dt2_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17379 entries, 2011-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   count         17379 non-null  int64
#  1   year          17379 non-null  object
#  2   month         17379 non-null  object
#  3   day_of_month  17379 non-null  int64
#  4   week_day      17379 non-null  object
#  5   month_number  17379 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 950.4+ KB

# %%
# Transform 'month_number' column type from 'int' to 'str' to later concatinate.

df_dt2_2['month_number']= df_dt2_2['month_number'].astype(str)
# Out:
# /var/folders/yq/6pm1lcds6ln5qlsjc5y8fly00000gn/T/ipykernel_10299/566047724.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt2_2['month_number']= df_dt2_2['month_number'].astype(str)

# %%
df_dt2_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17379 entries, 2011-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   count         17379 non-null  int64
#  1   year          17379 non-null  object
#  2   month         17379 non-null  object
#  3   day_of_month  17379 non-null  int64
#  4   week_day      17379 non-null  object
#  5   month_number  17379 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 950.4+ KB

# %%
# Concatinate 'year' and 'month_number' to create a new column called 'date' as 
# string type.

df_dt2_2['date'] = pd.to_datetime(df_dt2_2['year'] + '/' + df_dt2_2['month_number'])
df_dt2_2
# Out:
# /var/folders/yq/6pm1lcds6ln5qlsjc5y8fly00000gn/T/ipykernel_10299/823846508.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt2_2['date'] = pd.to_datetime(df_dt2_2['year'] + '/' + df_dt2_2['month_number'])
#                      count  year     month  day_of_month  week_day  \
# datetime
# 2011-01-01 00:00:00     16  2011   January             1  Saturday
# 2011-01-01 01:00:00     40  2011   January             1  Saturday
# 2011-01-01 02:00:00     32  2011   January             1  Saturday
# 2011-01-01 03:00:00     13  2011   January             1  Saturday
# 2011-01-01 04:00:00      1  2011   January             1  Saturday
# ...                    ...   ...       ...           ...       ...
# 2012-12-31 19:00:00    156  2012  December            31    Monday
# 2012-12-31 20:00:00    104  2012  December            31    Monday
# 2012-12-31 21:00:00     67  2012  December            31    Monday
# 2012-12-31 22:00:00     43  2012  December            31    Monday
# 2012-12-31 23:00:00     28  2012  December            31    Monday
#
#                     month_number       date
# datetime
# 2011-01-01 00:00:00            1 2011-01-01
# 2011-01-01 01:00:00            1 2011-01-01
# 2011-01-01 02:00:00            1 2011-01-01
# 2011-01-01 03:00:00            1 2011-01-01
# 2011-01-01 04:00:00            1 2011-01-01
# ...                          ...        ...
# 2012-12-31 19:00:00           12 2012-12-01
# 2012-12-31 20:00:00           12 2012-12-01
# 2012-12-31 21:00:00           12 2012-12-01
# 2012-12-31 22:00:00           12 2012-12-01
# 2012-12-31 23:00:00           12 2012-12-01
#
# [17379 rows x 7 columns]

# %%
# Transform 'date' column into a date.time type.

df_dt2_2['date'] = pd.to_datetime(df_dt2_2['date'])
df_dt2_2
# Out:
# /var/folders/yq/6pm1lcds6ln5qlsjc5y8fly00000gn/T/ipykernel_10299/2812342474.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt2_2['date'] = pd.to_datetime(df_dt2_2['date'])
#                      count  year     month  day_of_month  week_day  \
# datetime
# 2011-01-01 00:00:00     16  2011   January             1  Saturday
# 2011-01-01 01:00:00     40  2011   January             1  Saturday
# 2011-01-01 02:00:00     32  2011   January             1  Saturday
# 2011-01-01 03:00:00     13  2011   January             1  Saturday
# 2011-01-01 04:00:00      1  2011   January             1  Saturday
# ...                    ...   ...       ...           ...       ...
# 2012-12-31 19:00:00    156  2012  December            31    Monday
# 2012-12-31 20:00:00    104  2012  December            31    Monday
# 2012-12-31 21:00:00     67  2012  December            31    Monday
# 2012-12-31 22:00:00     43  2012  December            31    Monday
# 2012-12-31 23:00:00     28  2012  December            31    Monday
#
#                     month_number       date
# datetime
# 2011-01-01 00:00:00            1 2011-01-01
# 2011-01-01 01:00:00            1 2011-01-01
# 2011-01-01 02:00:00            1 2011-01-01
# 2011-01-01 03:00:00            1 2011-01-01
# 2011-01-01 04:00:00            1 2011-01-01
# ...                          ...        ...
# 2012-12-31 19:00:00           12 2012-12-01
# 2012-12-31 20:00:00           12 2012-12-01
# 2012-12-31 21:00:00           12 2012-12-01
# 2012-12-31 22:00:00           12 2012-12-01
# 2012-12-31 23:00:00           12 2012-12-01
#
# [17379 rows x 7 columns]

# %%
df_dt2_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17379 entries, 2011-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   count         17379 non-null  int64
#  1   year          17379 non-null  object
#  2   month         17379 non-null  object
#  3   day_of_month  17379 non-null  int64
#  4   week_day      17379 non-null  object
#  5   month_number  17379 non-null  object
#  6   date          17379 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 1.1+ MB

# %%
# Add a new column only with year and month

df_dt1['date'] = df_dt1.index.to_period('M')
df_dt1
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#                      humidity  windspeed  casual  registered  ...  year  \
# datetime                                                      ...
# 2011-01-01 00:00:00        81     0.0000     3.0        13.0  ...  2011
# 2011-01-01 01:00:00        80     0.0000     8.0        32.0  ...  2011
# 2011-01-01 02:00:00        80     0.0000     5.0        27.0  ...  2011
# 2011-01-01 03:00:00        75     0.0000     3.0        10.0  ...  2011
# 2011-01-01 04:00:00        75     0.0000     0.0         1.0  ...  2011
# ...                       ...        ...     ...         ...  ...   ...
# 2012-12-31 19:00:00        60    11.0014     NaN         NaN  ...  2012
# 2012-12-31 20:00:00        60    11.0014     NaN         NaN  ...  2012
# 2012-12-31 21:00:00        60    11.0014     NaN         NaN  ...  2012
# 2012-12-31 22:00:00        56     8.9981     NaN         NaN  ...  2012
# 2012-12-31 23:00:00        65     8.9981     NaN         NaN  ...  2012
#
#                      month_number     month day_of_month  week_day hour_day  \
# datetime
# 2011-01-01 00:00:00             1   January            1  Saturday        0
# 2011-01-01 01:00:00             1   January            1  Saturday        1
# 2011-01-01 02:00:00             1   January            1  Saturday        2
# 2011-01-01 03:00:00             1   January            1  Saturday        3
# 2011-01-01 04:00:00             1   January            1  Saturday        4
# ...                           ...       ...          ...       ...      ...
# 2012-12-31 19:00:00            12  December           31    Monday       19
# 2012-12-31 20:00:00            12  December           31    Monday       20
# 2012-12-31 21:00:00            12  December           31    Monday       21
# 2012-12-31 22:00:00            12  December           31    Monday       22
# 2012-12-31 23:00:00            12  December           31    Monday       23
#
#                      season_name hour_of_day  part_of_day     date
# datetime
# 2011-01-01 00:00:00       winter           0        night  2011-01
# 2011-01-01 01:00:00       winter           1        night  2011-01
# 2011-01-01 02:00:00       winter           2        night  2011-01
# 2011-01-01 03:00:00       winter           3        night  2011-01
# 2011-01-01 04:00:00       winter           4        night  2011-01
# ...                          ...         ...          ...      ...
# 2012-12-31 19:00:00       winter          19      evening  2012-12
# 2012-12-31 20:00:00       winter          20      evening  2012-12
# 2012-12-31 21:00:00       winter          21      evening  2012-12
# 2012-12-31 22:00:00       winter          22      evening  2012-12
# 2012-12-31 23:00:00       winter          23      evening  2012-12
#
# [17379 rows x 21 columns]

# %%
#Create a pivot_table to later plot in a Bar Chart

df_dt1.pivot_table(values=['count'],
                      columns='week_day',
                      index='date',
                      aggfunc='mean')
# Out:
#                count                                                  \
# week_day      Friday      Monday    Saturday      Sunday    Thursday
# date
# 2011-01    74.967742   49.333333   48.737288   54.367521   87.544304
# 2011-02   101.815217   89.457447   71.572917  100.236559   88.516129
# 2011-03   104.297872   98.913043  109.687500   85.956989   70.415254
# 2011-04   127.958333  146.147368  129.091667  157.760417  187.885417
# 2011-05   230.593750  186.000000  235.968750  197.825000  209.625000
# 2011-06   231.416667  202.864583  243.333333  231.708333  206.033333
# 2011-07   228.725000  201.072917  239.625000  220.341667  223.302083
# 2011-08   201.291667  178.300000  201.733333  193.348315  184.854167
# 2011-09   194.441667  171.800000  206.312500  207.583333  178.109244
# 2011-10   215.791667  186.725000  171.966667  196.541667  220.958333
# 2011-11   172.458333  170.147368  174.531250  184.552083  161.604167
# 2011-12   142.991667  126.294737  124.283333  115.589474  135.758333
# 2012-01   135.906250   79.655462  109.291667   93.025000  137.062500
# 2012-02   166.125000  136.063830  117.864583   98.885417  157.135417
# 2012-03   174.341667  187.145833  192.808333  183.042105  210.625000
# 2012-04   255.010417  196.521008  258.135417  215.008333  222.322917
# 2012-05   287.906250  201.333333  304.375000  264.791667  267.541667
# 2012-06   272.100000  247.614583  305.916667  307.322917  302.000000
# 2012-07   245.156250  247.433333  209.666667  220.850000  268.625000
# 2012-08   258.833333  234.250000  266.187500  207.593750  275.150000
# 2012-09   308.458333  266.364583  298.600000  285.708333  280.468750
# 2012-10   271.250000  238.721649  281.656250  220.645833  284.385417
# 2012-11   234.583333  219.229167  226.510417  224.208333  222.372881
# 2012-12   151.562500  158.336134  155.775000  121.791667  174.593750
#
#
# week_day     Tuesday   Wednesday
# date
# 2011-01    68.600000   56.726190
# 2011-02    75.147727   81.505376
# 2011-03    99.042017   82.898305
# 2011-04   115.302083  160.385417
# 2011-05   191.533333  172.635417
# 2011-06   210.791667  223.041667
# 2011-07   196.354167  215.375000
# 2011-08   192.241667  194.158333
# 2011-09   154.652632  144.677083
# 2011-10   200.500000  154.242105
# 2011-11   149.750000  160.691667
# 2011-12   136.604167   93.947368
# 2012-01   126.016949  105.927083
# 2012-02   148.231579  141.478992
# 2012-03   163.687500  206.312500
# 2012-04   245.708333  220.631579
# 2012-05   218.641667  233.066667
# 2012-06   251.218750  289.000000
# 2012-07   243.900000  278.343750
# 2012-08   241.343750  271.033333
# 2012-09   252.958333  291.281250
# 2012-10   243.906542  284.366667
# 2012-11   189.718750  221.916667
# 2012-12   201.200000  174.093750

# %%
pivot_table = df_dt1.pivot_table(values=['count', 'registered','casual'] ,
                      columns='week_day',
                      aggfunc='mean');

# %%
pivot_table
# Out:
# week_day        Friday      Monday    Saturday      Sunday    Thursday  \
# casual       31.001962   29.843972   63.625000   57.051298   24.007083
# count       200.249698  175.096410  194.396497  182.842126  198.999595
# registered  166.842381  160.546744  133.040404  123.788474  173.289118
#
# week_day       Tuesday   Wednesday
# casual       22.979207   22.521599
# count       180.951080  187.644040
# registered  166.744639  165.889749

# %%
df_dt1.pivot_table(values=['count', 'registered','casual'] ,
                      columns='week_day',
                      aggfunc='mean').plot(kind='bar');
